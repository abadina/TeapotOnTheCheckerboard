# %% [markdown]
# Importing modules

# %%
import numpy as np
import cv2
import glob

# This is a value for the termination criterion of the subpixel corner localizer
criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 30, 0.001)

# %% [markdown]
# Creation of the 3D point coordinates and loading images

# %%
# Here you have 3D points for the checkerboard (0,0,0), (1,0,0), (2,0,0) ....,(6,5,0)
objp = np.zeros((6*7,3), np.float32)
objp[:,:2] = np.mgrid[0:7,0:6].T.reshape(-1,2)
# Here you load the image files
images = glob.glob('left1.jpg')

print(images)
# Out:
# ['left1.jpg']

# %% [markdown]
# Cell 1

# %%
# Arrays to store object points and image points from all the images.
objpoints = [] # 3d point in real world space
imgpoints = [] # 2d points in image plane.
for fname in images:
    #reading an image
    img = cv2.imread(fname)
    # transforming the image to gray scale
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

    # Find the chess board corners
    ret, corners = cv2.findChessboardCorners(gray, (7,6),None)

    # If found, add object points, image points (after refining them)
    if ret == True:
        objpoints.append(objp)

        corners2 = cv2.cornerSubPix(gray,corners,(11,11),(-1,-1),criteria)
        imgpoints.append(corners2)
        
print(gray)
# Out:
# [[ 0  2  4 ...  0  0  0]
#  [ 1  2  4 ...  4  3  6]
#  [ 1  3  4 ...  6  5  3]
#  ...
#  [ 7 38 44 ... 56 47 11]
#  [ 6 35 38 ... 43 40  8]
#  [ 0 12 13 ... 12 14  0]]

# %% [markdown]
# Cell 2

# %%
retval, mtx, dist, rvecs, tvecs = cv2.calibrateCamera(objpoints, imgpoints, gray.shape[::-1],None,None)

# %%
print("rotation vector size",len(rvecs))
# Out:
# rotation vector size 1

# %%
for rvec in rvecs:
    R,jacobian=cv2.Rodrigues(rvec)
    print(jacobian)
    print("\n")
# Out:
# [[-0.26097886  0.28374583 -0.53739407 -0.14239609  0.01023     0.00667944
#   -0.59078544 -0.07106488  0.26314201]
#  [-0.01069833 -0.25458238 -0.03791587 -0.01756449  0.15016353 -0.63076033
#   -0.02646957 -0.57736896 -0.1463582 ]
#  [ 0.08538848  0.9045587   0.23534751 -0.96894414  0.0454136   0.14808597
#   -0.00167038 -0.27805596 -0.07578573]]

# %%
Rm=[]
for rvec in rvecs:
    R,jacobian=cv2.Rodrigues(rvec)
    Rm.append(R)
    print(R)
    print("\n")
    
print(Rm)
print(len(Rm))
# Out:
# [[-0.90445156 -0.0254109   0.42581881]
#  [-0.08042725 -0.97016312 -0.22872468]
#  [ 0.4189258  -0.24111783  0.87542182]]
#
#
# [array([[-0.90445156, -0.0254109 ,  0.42581881],
#        [-0.08042725, -0.97016312, -0.22872468],
#        [ 0.4189258 , -0.24111783,  0.87542182]])]
# 1

# %% [markdown]
# Camera matrix refinement

# %%
img = cv2.imread('left12.jpg')
h,  w = img.shape[:2]
newcameramtx, roi=cv2.getOptimalNewCameraMatrix(mtx,dist,(w,h),1,(w,h))

# %% [markdown]
# Cell 3

# %%
# 1
dst = cv2.undistort(img, mtx, dist, None, newcameramtx)

# crop the image
x,y,w,h = roi
dst = dst[y:y+h, x:x+w]
cv2.imwrite('calibresult1.png',dst)


# 2
mapx,mapy = cv2.initUndistortRectifyMap(mtx,dist,None,newcameramtx,(w,h),5)
dst = cv2.remap(img,mapx,mapy,cv2.INTER_LINEAR)

# crop the image
x,y,w,h = roi
dst = dst[y:y+h, x:x+w]
cv2.imwrite('calibresult2.png',dst)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-9-f99df49cafdd> in <module>
#      15 x,y,w,h = roi
#      16 dst = dst[y:y+h, x:x+w]
# ---> 17 cv2.imwrite('calibresult2.png',dst)
#
# error: OpenCV(4.5.1) C:\Users\appveyor\AppData\Local\Temp\1\pip-req-build-oduouqig\opencv\modules\imgcodecs\src\loadsave.cpp:753: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'

# %% [markdown]
# Cell 4

# %%
tot_error = 0
for i in range(len(objpoints)):
    imgpoints2, _ = cv2.projectPoints(objpoints[i], rvecs[i], tvecs[i], mtx, dist)
    error = cv2.norm(imgpoints[i],imgpoints2, cv2.NORM_L2)/len(imgpoints2)
    tot_error += error

print("total error: ", tot_error/len(objpoints))
# Out:
# total error:  0.022552185443330906

# %% [markdown]
# # Part B

# %% [markdown]
# # # 1

# %% [markdown]
# Load teapot point cloud coordinates

# %%
import pandas as pd
import matplotlib.animation

# %%
# Load from text file
tp= np.loadtxt("teapot.txt",usecols=range(3))
# Number of points in the cloud
n_points = np.shape(tp)
# Transpose and add a fourth coordinate with unitary value 
# (homogeneous coordinates)
tp = np.hstack((tp,np.ones((n_points[0],1),dtype=np.float))).T
# Save it in a data frame
df = pd.DataFrame({"x" : tp[0,:], "y" :tp[1,:], "z" : tp[2,:], 
                                                "w": tp[3,:]})

print(tp)
# Out:
# [[ 1.38137   1.4       1.35074  ...  0.350254  0.313617  0.228728]
#  [ 0.        0.       -0.375926 ...  0.097771  0.087529  0.063803]
#  [ 2.45469   2.4       2.4      ...  3.06667   2.98125   2.88333 ]
#  [ 1.        1.        1.       ...  1.        1.        1.      ]]

# %%
# Scaling matrix
def scaling_matrix(s):
    # Scales are given in numpy array s
    # s=np.array([s_x,s_y,s_z])
    
    # Write the scaling matrix here
    S = np.identity(4)
    S[:3, :3] = np.diag(s)
    
    return S

# Translation matrix
def translation_matrix(t):
    # Translation vector is given in numpy array t
    # t=np.array([t_x,t_y,t_z])
    
    # Write the translation matrix here
    T = np.identity(4)
    T[:3, 3] = t
    
    return T

# Rotation matrix
def rotation_matrix(theta, v):
    # Axis for rotation (unit norm vector) is given 
    # is given in numpy array v
    # v=np.array([v_x,v_y,v_z])
    # Rotation angle is given in theta
    
    # Write the rotation matrix here
    st = np.sin(theta)
    ct = np.cos(theta)
    o_ct = 1-ct
    vx2= v[0]**2
    vy2= v[1]**2
    vz2= v[2]**2
    vxy = v[0]*v[1]
    vxz = v[0]*v[2]
    vyz= v[1]*v[2]
    # Rotation
    R = [[ct+vx2*o_ct, vxy*o_ct-v[2]*st, vxz*o_ct+v[1]*st],
         [vxy*o_ct+v[2]*st, ct+vy2*o_ct, vyz*o_ct-v[0]*st],
         [vxz*o_ct-v[1]*st, vyz*o_ct+v[0]*st, ct+vz2*o_ct]]
    R_v = np.identity(4)
    R_v[:3, :3] = R
    
    return R_v

# %% [markdown]
# mtx : intrinsic matrix (Mint)
# R: rotation matrix
# t: translation matrix
#
# [R t] : extrinsic matrix (Mext)
#
#
# Camera matrix= Mint Mext

# %%
Mext=[]
for i in range(len(Rm)):
    Rt_matrix = np.concatenate((Rm[i],tvecs[i]), axis=1)
    Mext.append(Rt_matrix)
    print(Rt_matrix)
    print("\n")
# Out:
# [[-0.90445156 -0.0254109   0.42581881  4.76671966]
#  [-0.08042725 -0.97016312 -0.22872468 -1.27078405]
#  [ 0.4189258  -0.24111783  0.87542182 22.62597546]]

# %%
import numpy

# %%
Ms=[]
for i in range(len(Rm)):
    M=numpy.matmul(mtx,Mext)
    Ms.append(M)
    print(M)
    print("\n")
# Out:
# [[[-6.35075559e+02 -9.36638467e+01  6.20600242e+02  1.07927478e+04]
#   [ 6.63646962e+01 -8.46634631e+02  9.04373037e+01  6.02847906e+03]
#   [ 4.18925804e-01 -2.41117826e-01  8.75421821e-01  2.26259755e+01]]]

# %%
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
def update_graph(num):
    # Load point cloud from data frame
    tp=np.vstack((df['x'],df['y'],df['z'],df['w']))
    angle = num*0.01
    # Create uniform scaling matrix 
    M = scaling_matrix([0.5,0.5,-0.5])
    #M = scaling_matrix([1.0,1.0,1.0])
    tp_r = np.dot(M,tp)
    graph._offsets3d = (tp_r[0,:], tp_r[1,:], tp_r[2,:])
    return graph

# %%
# 3D figure generation

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
title = ax.set_title('Teapot')

# 3D scatter plot
graph = ax.scatter(tp[0,:], tp[1,:], tp[2,:])
# # Change axis limits if necessary
# ax.set_xlim3d(-8, 8)
# ax.set_ylim3d(-8, 8)
# ax.set_zlim3d(-1, 8)

# Animation function
ani = matplotlib.animation.FuncAnimation(fig, update_graph,1000, 
                                            interval=1, blit=False)


plt.show()

# %%
tp1=update_graph(1000)

tp2=np.ndarray((4,1177))
#print(tp1._offsets3d)
#print("\n")
print(tp1._offsets3d[0])
#print("\n")
print(tp1._offsets3d[1])
#print("\n")
print(tp1._offsets3d[2])

print("\n")
print("tp")
print(tp)
print(type(tp))
print(tp.shape)
#print(tp2)
print("\n")
tp2[0]=(tp1._offsets3d[0])
tp2[1]=(tp1._offsets3d[1])
tp2[2]=(tp1._offsets3d[2])
print("hello")
print(tp2)
# Out:
# [0.690685  0.7       0.67537   ... 0.175127  0.1568085 0.114364 ]
# [ 0.         0.        -0.187963  ...  0.0488855  0.0437645  0.0319015]
# [-1.227345 -1.2      -1.2      ... -1.533335 -1.490625 -1.441665]
#
#
# tp
# [[ 1.38137   1.4       1.35074  ...  0.350254  0.313617  0.228728]
#  [ 0.        0.       -0.375926 ...  0.097771  0.087529  0.063803]
#  [ 2.45469   2.4       2.4      ...  3.06667   2.98125   2.88333 ]
#  [ 1.        1.        1.       ...  1.        1.        1.      ]]
# <class 'numpy.ndarray'>
# (4, 1177)
#
#
# hello
# [[ 0.690685   0.7        0.67537   ...  0.175127   0.1568085  0.114364 ]
#  [ 0.         0.        -0.187963  ...  0.0488855  0.0437645  0.0319015]
#  [-1.227345  -1.2       -1.2       ... -1.533335  -1.490625  -1.441665 ]
#  [ 1.         1.         1.        ...  1.         1.         1.       ]]

# %%
import matplotlib.image as mpimg
from mpl_toolkits.mplot3d import Axes3D



#tp1=update_graph(1000)
u_sim=np.dot(M,tp2)
print(M)
print("\n")
print(tp)
print("\n")
print(u_sim)
print("\n")
print(u_sim[0])
print("\n")
print(len(u_sim[0]))
print(len(tp))
u_sim=u_sim/u_sim[0][2,:]

img=mpimg.imread('left1.jpg')
plt.imshow(img)
plt.scatter(u_sim[0][0,:],u_sim[0][1,:])


plt.show()

#img=mpimg.imread('left1.jpg')
#plt.imshow(img)
#scatter=plt.scatter(tp[0,:],tp[1,:],s=2)
#fig,ax = plt.subplots()
#ax.imshow(img)
#plt.show()
# Out:
# [[[-6.35075559e+02 -9.36638467e+01  6.20600242e+02  1.07927478e+04]
#   [ 6.63646962e+01 -8.46634631e+02  9.04373037e+01  6.02847906e+03]
#   [ 4.18925804e-01 -2.41117826e-01  8.75421821e-01  2.26259755e+01]]]
#
#
# [[ 1.38137   1.4       1.35074  ...  0.350254  0.313617  0.228728]
#  [ 0.        0.       -0.375926 ...  0.097771  0.087529  0.063803]
#  [ 2.45469   2.4       2.4      ...  3.06667   2.98125   2.88333 ]
#  [ 1.        1.        1.       ...  1.        1.        1.      ]]
#
#
# [[[9592.42001619 9603.47460099 9636.72184962 ... 9725.36202911
#    9763.98114965 9822.4323363 ]
#   [5963.31838338 5966.4095786  6123.91100125 ... 5860.04246551
#    5867.02495701 5878.67957768]
#   [  21.84087663   21.86871733   21.90372042 ...   21.34523859
#      21.37618853   21.40412847]]]
#
#
# [[9592.42001619 9603.47460099 9636.72184962 ... 9725.36202911
#   9763.98114965 9822.4323363 ]
#  [5963.31838338 5966.4095786  6123.91100125 ... 5860.04246551
#   5867.02495701 5878.67957768]
#  [  21.84087663   21.86871733   21.90372042 ...   21.34523859
#     21.37618853   21.40412847]]
#
#
# 3
# 4

# %%
import matplotlib.image as mpimg
from mpl_toolkits.mplot3d import Axes3D



#tp1=update_graph(1000)
u_sim=np.dot(M,tp)
print(M)
print("\n")
print(tp)
print("\n")
print(u_sim)
print("\n")
print(u_sim[0])
print("\n")
print(len(u_sim[0]))
print(len(tp))
u_sim=u_sim/u_sim[0][2,:]

img=mpimg.imread('left1.jpg')
plt.imshow(img)
plt.scatter(u_sim[0][0,:],u_sim[0][1,:])


plt.show()

#img=mpimg.imread('left1.jpg')
#plt.imshow(img)
#scatter=plt.scatter(tp[0,:],tp[1,:],s=2)
#fig,ax = plt.subplots()
#ax.imshow(img)
#plt.show()
# Out:
# [[[-6.35075559e+02 -9.36638467e+01  6.20600242e+02  1.07927478e+04]
#   [ 6.63646962e+01 -8.46634631e+02  9.04373037e+01  6.02847906e+03]
#   [ 4.18925804e-01 -2.41117826e-01  8.75421821e-01  2.26259755e+01]]]
#
#
# [[ 1.38137   1.4       1.35074  ...  0.350254  0.313617  0.228728]
#  [ 0.        0.       -0.375926 ...  0.097771  0.087529  0.063803]
#  [ 2.45469   2.4       2.4      ...  3.06667   2.98125   2.88333 ]
#  [ 1.        1.        1.       ...  1.        1.        1.      ]]
#
#
# [[[11438.85466738 11393.08258246 11459.57707972 ... 12464.32856595
#    12435.54346162 12430.90748344]
#   [ 6342.14880119  6338.43915934  6653.44200464 ...  6246.2886077
#     6244.80328173  6250.40128151]
#   [   25.35355618    25.31348395    25.38349013 ...    25.4337614
#       25.34610421    25.23054148]]]
#
#
# [[11438.85466738 11393.08258246 11459.57707972 ... 12464.32856595
#   12435.54346162 12430.90748344]
#  [ 6342.14880119  6338.43915934  6653.44200464 ...  6246.2886077
#    6244.80328173  6250.40128151]
#  [   25.35355618    25.31348395    25.38349013 ...    25.4337614
#      25.34610421    25.23054148]]
#
#
# 3
# 4

# %%
s_im = 1./np.std(u_im,1)[0:2]
t_im = -(np.mean(u_im,1)[0:2])
diag_s = np.diag(s_im)
T_im = np.hstack((diag_s,(s_im*t_im).reshape(-1,1)))
T_im = np.vstack((T_im,np.array([0,0,1])))
u_im_t = np.dot(T_im,u_im)
print(u_im_t)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-a9a7afe4a6a0> in <module>
# ----> 1 s_im = 1./np.std(u_im,1)[0:2]
#       2 t_im = -(np.mean(u_im,1)[0:2])
#       3 diag_s = np.diag(s_im)
#       4 T_im = np.hstack((diag_s,(s_im*t_im).reshape(-1,1)))
#       5 T_im = np.vstack((T_im,np.array([0,0,1])))
#
# NameError: name 'u_im' is not defined

# %%
u_w_i=np.transpose(u_w_t[:,0].reshape(-1,1))
print(u_w_i)
A_i_1=np.hstack((np.zeros((1,4)),-u_w_i,u_im_t[1,0]*u_w_i))
A_i_2=np.hstack((u_w_i,np.zeros((1,4)),-u_im_t[0,0]*u_w_i))
A    = np.vstack((A_i_1,A_i_2))

# Stacking matrices for each point correspondence
for i in range(1,N):    
    u_w_i=np.transpose(u_w_t[:,i].reshape(-1,1))
    A_i_1=np.hstack((np.zeros((1,4)),-u_w_i,u_im_t[1,i]*u_w_i))
    A_i_2=np.hstack((u_w_i,np.zeros((1,4)),-u_im_t[0,i]*u_w_i))
    A    = np.vstack((A,A_i_1,A_i_2))
print(A)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-3aaa1cbfbbb7> in <module>
# ----> 1 u_w_i=np.transpose(u_w_t[:,0].reshape(-1,1))
#       2 print(u_w_i)
#       3 A_i_1=np.hstack((np.zeros((1,4)),-u_w_i,u_im_t[1,0]*u_w_i))
#       4 A_i_2=np.hstack((u_w_i,np.zeros((1,4)),-u_im_t[0,0]*u_w_i))
#       5 A    = np.vstack((A_i_1,A_i_2))
#
# NameError: name 'u_w_t' is not defined

# %%
img=mpimg.imread('left1.jpg')
fig,ax = plt.subplots()
ax.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-07ded3a58b3b> in <module>
# ----> 1 img=mpimg.imread('left1.jpg')
#       2 fig,ax = plt.subplots()
#       3 ax.imshow(img)
#
# NameError: name 'mpimg' is not defined
